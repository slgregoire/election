# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_file = "https://raw.githubusercontent.com/tonmcg/us-presidential-election-results/master/public/data/chr.csv"

# %%
# %matplotlib inline

# %%
pd.options.display.max_columns = 150
pd.options.display.max_info_columns = 150

# %%
data = pd.read_csv(data_file)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 125 columns):
# id                                     3141 non-null int64
# FIPS                                   3141 non-null int64
# County                                 3141 non-null object
# State                                  3141 non-null object
# GOP Votes                              3141 non-null int64
# Democratic Votes                       3141 non-null int64
# Other Votes                            3141 non-null int64
# Total Votes                            3141 non-null int64
# County Winner                          3141 non-null object
# Avg Daily Sunlight (KJ/m²)             3107 non-null float64
# % Uninsured                            3141 non-null float64
# % Unemployed                           3141 non-null float64
# Providers                              3136 non-null float64
# Black/White Segregation index          2035 non-null float64
# ...

# %%
data.head()
# Out:
#      id  FIPS                  County State  GOP Votes  Democratic Votes  \
# 0  1105  1105            Perry County    AL       1403              3823
# 1  2013  2013  Aleutians East Borough    AK     130413             93003
# 2  2050  2050      Bethel Census Area    AK     130413             93003
# 3  2068  2068          Denali Borough    AK     130413             93003
# 4  2070  2070  Dillingham Census Area    AK     130413             93003
#
#    Other Votes  Total Votes County Winner  Avg Daily Sunlight (KJ/m²)  \
# 0         5284        10510       Clinton                    17096.14
# 1       269760       493176         Trump                         NaN
# 2       269760       493176         Trump                         NaN
# 3       269760       493176         Trump                         NaN
# 4       269760       493176         Trump                         NaN
#
#    % Uninsured  % Unemployed  Providers  Black/White Segregation index  \
# ...

# %%
columns_to_drop = [col for col in data.columns if 'CIH' in col or 'CIL' in col or 'Quartile' in col]
data_no_ci = data.drop(columns_to_drop, axis=1)

# %%
data_no_ci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 56 columns):
# id                                  3141 non-null int64
# FIPS                                3141 non-null int64
# County                              3141 non-null object
# State                               3141 non-null object
# GOP Votes                           3141 non-null int64
# Democratic Votes                    3141 non-null int64
# Other Votes                         3141 non-null int64
# Total Votes                         3141 non-null int64
# County Winner                       3141 non-null object
# Avg Daily Sunlight (KJ/m²)          3107 non-null float64
# % Uninsured                         3141 non-null float64
# % Unemployed                        3141 non-null float64
# Providers                           3136 non-null float64
# Black/White Segregation index       2035 non-null float64
# Drug Overdose Mortality Rate        1625 non-null float64
# ...

# %%
data_no_ci.isnull().sum()
# Out:
# id                                     0
# FIPS                                   0
# County                                 0
# State                                  0
# GOP Votes                              0
# Democratic Votes                       0
# Other Votes                            0
# Total Votes                            0
# County Winner                          0
# Avg Daily Sunlight (KJ/m²)            34
# % Uninsured                            0
# % Unemployed                           0
# Providers                              5
# Black/White Segregation index       1106
# Drug Overdose Mortality Rate        1516
# Household Income                       6
# % Disconnected Youth                1095
# Teen Birth Rate                      112
# Violent Crime Rate                   175
# Population                             6
# Physically Unhealthy Days              6
# PCP Rate                             138
# MHP Rate                             293
# ...

# %% [markdown]
# maybe work with variables that have fewer than X number of nulls and also intuitively seem likely to be important??? if nothign else, maybe this makes sense as a solid first effort.
